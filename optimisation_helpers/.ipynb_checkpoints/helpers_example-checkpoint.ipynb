# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from helpers import Opt_Helpers, BT_Helpers, Stats_Helpers
from pandas_datareader import data

# %%
"""Define parameters for data request."""

tickers = ['AGG', 'EBND', 'URTH', 'EEM']
data_source = 'yahoo'
start_date = '2014-03-31'
end_date = '2018-03-31'

# %%
"""Request data, ensure sorted by ascending date, and normalise."""

panel_data = data.DataReader(tickers, data_source, start_date, end_date)
px_data = panel_data.loc['Adj Close'].dropna().sort_index(ascending=True)
px_data = px_data / px_data.iloc[0]

# %%
"""Initialise optimisation class with price data."""

opt = Opt_Helpers(px_data, rf=0.0, scaling_fact=252)

# %%
"""
TEST CASE
Add constraints: Portfolio weights must sum to 100%, minimum ann. return > 3.0%,
Add boundaries: Long only, no short positions.
"""

min_ret = 0.035

cons = (
    {'type': 'eq', 'fun': lambda w: np.sum(w) - 1}
)

bnds = tuple((0, 1) for x in px_data.columns)

# %%
"""Run optimisation."""

opt.port_optimisation(opt.max_sr, constraints=cons, bounds=bnds)
# Out:
# Optimization terminated successfully. Success==True after 8 iterations.
# Total time: 0.12661433219909668 secs

# %%
"""Class attributes store optimised weights."""

opt.weights
# Out:
# array([ 0.83699375,  0.        ,  0.        ,  0.16300625])

# %%
"""Initialise backtest class."""


rf = 0.0
bt = BT_Helpers(px_data, opt_period = 365, val_period = 90, rf=rf, scaling_fact=252)

# %%
"""Generate historical optimisation weights."""

max_er = bt.bt_optimisation(func='max_er', constraints=cons, bounds=bnds)
max_er_ts = bt.bt_timeseries()

min_vol = bt.bt_optimisation(func='min_vol', constraints=cons, bounds=bnds)
min_vol_ts = bt.bt_timeseries()

max_sr = bt.bt_optimisation(func='max_sr', constraints=cons, bounds=bnds)
max_sr_ts = bt.bt_timeseries()


risk_parity = bt.bt_optimisation(func='risk_parity', constraints=cons, bounds=bnds)
risk_parity_ts = bt.bt_timeseries()


max_dr = bt.bt_optimisation(func='max_dr', constraints=cons, bounds=bnds)
max_dr_ts = bt.bt_timeseries()
# Out:
# Total time: 1.0951800346374512 secs
# Total time: 1.2590112686157227 secs
# Total time: 1.172804355621338 secs
# Total time: 1.7832505702972412 secs
# Total time: 1.4086596965789795 secs

# %%
"""Create df of individual results."""
comp_df = pd.concat([max_er_ts.NAV, min_vol_ts.NAV, max_sr_ts.NAV, risk_parity_ts.NAV, max_dr_ts.NAV], axis=1)
comp_df.columns = ['max_er', 'min_vol', 'max_sr', 'risk_parity', 'max_dr']

# %%
"""Plot and compare optimisation results."""

#TODO tcraw88 Fix Rebalancing Bug

comp_df.plot(figsize=(15,10))
plt.legend(loc='best');

# %%
"""Initialise stats class."""

st = Stats_Helpers()

# %%
"""View summary statistics."""

st.stats_summary(comp_df, rf=rf)
# Out:
#                 max_er   min_vol    max_sr  risk_parity    max_dr
# exp_return    0.081436  0.024045  0.042117     0.036365  0.033091
# volatility    0.164118  0.030827  0.084280     0.043287  0.036550
# sharpe_ratio  0.496202  0.779982  0.499730     0.840075  0.905351
# max_drawdown -0.166738 -0.039609 -0.124896    -0.072508 -0.052410
